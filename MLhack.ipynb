# %%
import matplotlib.pyplot as plt
import librosa.display 
import numpy as np
import scipy
import sklearn.metrics 
from IPython.display import Audio

# %%
new = librosa.load("new2.wav")

# %%
real_song = librosa.load("test_real.wav")

# %%
from scipy.interpolate import splrep, splev

plt.figure()
bspl = splrep(x,song[0],s=5)
bspl_y = splev(x,bspl)
plt.plot(x,song[0])
plt.plot(x,bspl_y)
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)

a = fig.add_subplot(1, 1, 1)
x = np.linspace(-1, 20, 1000)
y1 = [np.sin(i*4)-np.exp(-i+2) + 2 for i in x]
y2 = [np.sin(i*4)-np.exp(-i+2) + 4 for i in x]

a.hlines(5, -5, 20, color='black')
a.hlines(0, -5, 20, color='black')

a.plot(x, y2, color='red')
a.plot(x, y1, color='blue')
a.grid(True)

# %%
C = np.abs(librosa.cqt(song[0], song[1]))

# %%
librosa.display.specshow(librosa.amplitude_to_db(C, ref=np.max),
                         sr=song[1], x_axis='time', y_axis='cqt_note')
